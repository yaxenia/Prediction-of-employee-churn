# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st
from sklearn import ensemble, tree, linear_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-2a1c0bee65a5> in <module>
#       6 import seaborn as sns
#       7 import scipy.stats as st
# ----> 8 from sklearn import ensemble, tree, linear_model
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/Users/liza/Downloads/WA_Fn-UseC_-HR-Employee-Attrition.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.columns[data.isnull().sum() != 0]
# Out:
# Index([], dtype='object')

# %% [markdown]
# В наших данных нет пропущенных значений.

# %%
df = pd.DataFrame(data=data.nunique(), columns=['nunique'], dtype=int) # nunique - уникальные значения
df['nunique(%)'] = data.nunique()/len(data) * 100 

df['pass'] = data.isnull().sum() # pass - пропуски

for column in categorical_columns:
    df['median'] = None
    df['std'] = None
    df['min'] = None
    df['max'] = None
    

df['mean'] = data[num_columns].mean()
df['std'] = data[num_columns].std()
df['min'] = data[num_columns].min()
df['max'] = data[num_columns].max()
df['type'] = data.dtypes
df.head()
# Out:
#                 nunique  nunique(%)  pass median         std    min     max  \
# Age                  43    2.925170     0   None    9.135373   18.0    60.0
# Attrition             2    0.136054     0   None         NaN    NaN     NaN
# BusinessTravel        3    0.204082     0   None         NaN    NaN     NaN
# DailyRate           886   60.272109     0   None  403.509100  102.0  1499.0
# Department            3    0.204082     0   None         NaN    NaN     NaN
#
#                       mean    type
# Age              36.923810   int64
# Attrition              NaN  object
# BusinessTravel         NaN  object
# DailyRate       802.485714   int64
# Department             NaN  object

# %% [markdown]
# Удалим три константных признака, они не имеют никакой важности для построения модели.

# %%
data.drop(['EmployeeCount', 'Over18', 'StandardHours'], axis = 1, inplace=True)

# %% [markdown]
# Теперь разберемся с EmployeeNumber. Судя по всему это уникальный номер каждого сотрудника (повторений нет и не может быть), можно заменить этот столбец на столбец индексов.

# %%
data = data.set_index('EmployeeNumber')

# %%
categorical_columns = data.columns[data.dtypes == 'object']
num_columns = data.columns[data.dtypes == 'float64'].union(data.columns[data.dtypes == 'int64'])
len(categorical_columns), len(num_columns)
# Out:
# (8, 23)

# %% [markdown]
# Таким образом, в наших данных 8 категориальных признаков и 23 числовых.

# %% [markdown]
# При подготовке данных для моделей машинного обучения необходимо проанализировать все выбросы

# %% [markdown]
# Займемся поиском аномальных значений в данных (выбросов). Так как большинство признаков далеки от нормального распределения, воспользуемся методом IQR.
# IQR вычисляется, как разница между 75 и 25 перцентилями

# %%
import numpy as np 

for num_col in num_columns:
    q25, q75 = np.percentile(data[num_col], 25), np.percentile(data[num_col], 75)
    iqr = q75 - q25
    
    cut_off = iqr * 1.5
    lower, upper = q25 - cut_off, q75 + cut_off
    
    outliers = [x for x in data[num_col] if x < lower or x > upper]
    
    
    if len(outliers) != 0:
        
        print(num_col)
        print(lower, upper)
        print(outliers)
# Out:
# MonthlyIncome
# -5291.0 16581.0
# [19094, 18947, 19545, 18740, 18844, 18172, 17328, 16959, 19537, 17181, 19926, 19033, 18722, 19999, 16792, 19232, 19517, 19068, 19202, 19436, 16872, 19045, 19144, 17584, 18665, 17068, 19272, 18300, 16659, 19406, 19197, 19566, 18041, 17046, 17861, 16835, 16595, 19502, 18200, 16627, 19513, 19141, 19189, 16856, 19859, 18430, 17639, 16752, 19246, 17159, 17924, 17099, 17444, 17399, 19419, 18303, 19973, 19845, 17650, 19237, 19627, 16756, 17665, 16885, 17465, 19626, 19943, 18606, 17048, 17856, 19081, 17779, 19740, 18711, 18265, 18213, 18824, 18789, 19847, 19190, 18061, 17123, 16880, 17861, 19187, 19717, 16799, 17328, 19701, 17169, 16598, 17007, 16606, 19586, 19331, 19613, 17567, 19049, 19658, 17426, 17603, 16704, 19833, 19038, 19328, 19392, 19665, 16823, 17174, 17875, 19161, 19636, 19431, 18880]
# NumCompaniesWorked
# -3.5 8.5
# [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# PerformanceRating
# 3.0 3.0
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# StockOptionLevel
# -1.5 2.5
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# TotalWorkingYears
# -7.5 28.5
# [31, 29, 37, 38, 30, 40, 36, 34, 32, 33, 37, 30, 36, 31, 33, 32, 37, 31, 32, 32, 30, 34, 30, 40, 29, 35, 31, 33, 31, 29, 32, 30, 33, 30, 29, 31, 32, 33, 36, 34, 31, 36, 33, 31, 29, 33, 29, 32, 31, 35, 29, 32, 34, 36, 32, 30, 36, 29, 34, 37, 29, 29, 35]
# TrainingTimesLastYear
# 0.5 4.5
# [0, 5, 5, 5, 6, 5, 5, 5, 6, 6, 0, 0, 0, 5, 0, 5, 5, 5, 6, 6, 5, 0, 6, 5, 5, 0, 5, 5, 6, 5, 5, 5, 0, 5, 5, 5, 5, 6, 6, 5, 5, 5, 5, 0, 0, 5, 5, 5, 6, 6, 5, 0, 5, 0, 5, 5, 0, 6, 0, 5, 5, 6, 6, 5, 6, 5, 0, 5, 5, 5, 5, 0, 6, 5, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 0, 5, 0, 5, 5, 6, 5, 6, 5, 0, 5, 5, 0, 6, 6, 5, 6, 0, 5, 0, 6, 6, 6, 6, 5, 5, 0, 5, 0, 0, 6, 0, 6, 5, 6, 5, 5, 0, 5, 6, 6, 5, 5, 0, 0, 6, 0, 0, 5, 0, 5, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 0, 6, 6, 5, 5, 0, 0, 6, 6, 0, 5, 0, 0, 0, 0, 0, 5, 5, 6, 5, 5, 0, 5, 5, 0, 5, 5, 6, 5, 5, 5, 6, 5, 5, 5, 0, 0, 5, 5, 5, 5, 6, 0, 0, 6, 6, 6, 6, 5, 5, 5, 6, 5, 0, 5, 5, 6, 5, 6, 6, 5, 6, 6, 5, 0, 5, 5, 5, 5, 5, 0, 0, 0, 6, 5, 6, 6, 5, 6, 0, 6, 6, 5, 6, 6, 5, 5, 5, 0]
# YearsAtCompany
# -6.0 18.0
# [25, 22, 22, 27, 21, 22, 37, 25, 20, 40, 20, 24, 20, 24, 33, 20, 19, 22, 33, 24, 19, 21, 20, 36, 20, 20, 22, 24, 21, 21, 25, 21, 29, 20, 27, 20, 31, 32, 20, 20, 21, 22, 22, 34, 24, 26, 31, 20, 31, 26, 19, 21, 21, 32, 21, 19, 20, 22, 20, 21, 26, 20, 22, 24, 33, 29, 25, 21, 19, 19, 20, 19, 33, 19, 19, 20, 20, 20, 20, 20, 32, 20, 21, 33, 36, 26, 30, 22, 23, 23, 21, 21, 22, 22, 19, 22, 19, 22, 20, 20, 20, 22, 20, 20]
# YearsInCurrentRole
# -5.5 14.5
# [15, 16, 18, 15, 18, 17, 16, 15, 16, 15, 16, 16, 15, 16, 17, 15, 15, 15, 17, 17, 16]
# YearsSinceLastPromotion
# -4.5 7.5
# [8, 15, 8, 8, 9, 13, 12, 10, 11, 9, 12, 15, 15, 15, 9, 11, 11, 9, 12, 11, 15, 11, 10, 9, 11, 9, 8, 11, 11, 8, 13, 9, 9, 12, 10, 11, 15, 13, 9, 11, 10, 8, 8, 11, 9, 11, 12, 11, 14, 13, 14, 8, 11, 15, 10, 11, 11, 15, 11, 13, 11, 13, 15, 8, 13, 15, 11, 14, 15, 15, 9, 11, 9, 8, 9, 15, 11, 12, 9, 8, 10, 14, 8, 13, 13, 12, 14, 8, 8, 8, 14, 14, 8, 12, 13, 14, 14, 12, 11, 8, 11, 9, 12, 8, 9, 11, 9]
# YearsWithCurrManager
# -5.5 14.5
# [17, 15, 15, 15, 15, 17, 16, 17, 15, 17, 17, 17, 17, 16]

# %% [markdown]
# Мы выводим название столбца, в котором есть выбросы, диапазон, в который значения столбца должны входить, и список аномальных значений.

# %% [markdown]
# PerformanceRating:
# 1 'Low'
# 2 'Good'
# 3 'Excellent'
# 4 ‘Outstanding'

# %% [markdown]
# PerformanceRating, StockOptionLevel - это закодированные признаки one hot так что можно не рассматривать их как выбросы.

# %%
data.WorkLifeBalance.value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
q25, q75 = np.percentile(data['WorkLifeBalance'], 25), np.percentile(data['WorkLifeBalance'], 75)
q25, q75
iqr = q75 - q25
iqr
# Out:
# 1.0

# %%
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off
lower, upper
# Out:
# (0.5, 4.5)

# %%
outliers = [x for x in data['Age'] if x < lower or x > upper]

data.loc[data['YearsAtCompany'].isin(outliers)]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 31 columns]

# %%
diff = data['Age'] - data['YearsAtCompany'] 
data.loc[(data['YearsAtCompany'].isin(outliers))  & (diff < 18)]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 31 columns]

# %%
outliers_removed = [x for x in data['YearsAtCompany'] if x > lower and x < upper]
len(outliers_removed)
# Out:
# 246

# %% [markdown]
# Посмотрим на пропорции целевой переменной

# %%
data.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data.groupby('Attrition').describe()
# Out:
#               Age                                                   DailyRate  \
#             count       mean      std   min   25%   50%   75%   max     count
# Attrition
# No         1233.0  37.561233  8.88836  18.0  31.0  36.0  43.0  60.0    1233.0
# Yes         237.0  33.607595  9.68935  18.0  28.0  32.0  39.0  58.0     237.0
#
#                        ... YearsSinceLastPromotion       YearsWithCurrManager  \
#                  mean  ...                     75%   max                count
# Attrition              ...
# No         812.504461  ...                     3.0  15.0               1233.0
# Yes        750.362869  ...                     2.0  15.0                237.0
#
#
#                mean       std  min  25%  50%  75%   max
# Attrition
# No         4.367397  3.594116  0.0  2.0  3.0  7.0  17.0
# Yes        2.852321  3.143349  0.0  0.0  2.0  5.0  14.0
#
# [2 rows x 184 columns]

# %%
data.Attrition.value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# Данные не являются сбалансированными относительно целевой переменной. Покажем это с помощью графиков.

# %%
colors = ['#7f548f','#c9e5f4']

f,ax = plt.subplots(1,2, figsize=(15,10))
data.Attrition.value_counts().plot.pie(explode=[0,0.20], colors = colors, autopct='%1.1f%%',ax=ax[0])
sns.countplot('Attrition',data=data, palette = colors)
plt.show()

# %% [markdown]
# Построим матрицу корреляций, чтобы найти наиболее коррелирующие между собой признаки.

# %%
corr = data[num_columns].corr()

fig, ax = plt.subplots(figsize=(26, 20))

sns.heatmap(corr, cmap="BuPu", annot=True, fmt=".2f")

plt.xticks(range(len(corr.columns)), corr.columns)

plt.yticks(range(len(corr.columns) + 1), corr.columns) # о - белый 

plt.show()

# %%
data.corr()[lambda x: x > 0.7].head()
# Out:
#                          Age  DailyRate  DistanceFromHome  Education  \
# Age                      1.0        NaN               NaN        NaN
# DailyRate                NaN        1.0               NaN        NaN
# DistanceFromHome         NaN        NaN               1.0        NaN
# Education                NaN        NaN               NaN        1.0
# EnvironmentSatisfaction  NaN        NaN               NaN        NaN
#
#                          EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                          NaN         NaN             NaN
# DailyRate                                    NaN         NaN             NaN
# DistanceFromHome                             NaN         NaN             NaN
# Education                                    NaN         NaN             NaN
# EnvironmentSatisfaction                      1.0         NaN             NaN
#
#                          JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# Age                           NaN              NaN            NaN  ...
# DailyRate                     NaN              NaN            NaN  ...
# DistanceFromHome              NaN              NaN            NaN  ...
# Education                     NaN              NaN            NaN  ...
# EnvironmentSatisfaction       NaN              NaN            NaN  ...
#
#                          PerformanceRating  RelationshipSatisfaction  \
# Age                                    NaN                       NaN
# DailyRate                              NaN                       NaN
# DistanceFromHome                       NaN                       NaN
# Education                              NaN                       NaN
# EnvironmentSatisfaction                NaN                       NaN
#
#                          StockOptionLevel  TotalWorkingYears  \
# Age                                   NaN                NaN
# DailyRate                             NaN                NaN
# DistanceFromHome                      NaN                NaN
# Education                             NaN                NaN
# EnvironmentSatisfaction               NaN                NaN
#
#                          TrainingTimesLastYear  WorkLifeBalance  \
# Age                                        NaN              NaN
# DailyRate                                  NaN              NaN
# DistanceFromHome                           NaN              NaN
# Education                                  NaN              NaN
# EnvironmentSatisfaction                    NaN              NaN
#
#                          YearsAtCompany  YearsInCurrentRole  \
# Age                                 NaN                 NaN
# DailyRate                           NaN                 NaN
# DistanceFromHome                    NaN                 NaN
# Education                           NaN                 NaN
# EnvironmentSatisfaction             NaN                 NaN
#
#                          YearsSinceLastPromotion  YearsWithCurrManager
# Age                                          NaN                   NaN
# DailyRate                                    NaN                   NaN
# DistanceFromHome                             NaN                   NaN
# Education                                    NaN                   NaN
# EnvironmentSatisfaction                      NaN                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Из графиков корреляции видно, что довольно много наших столбцов плохо коррелируют друг с другом. Как правило, при создании прогнозирующей модели было бы предпочтительнее обучать модель с функциями, которые не слишком связаны друг с другом, чтобы нам не приходилось иметь дело с избыточными функциями. В случае, если у нас достаточно много взаимосвязанных функций, возможно, можно применить такую ​​методику, как анализ основных компонентов (PCA), чтобы уменьшить пространство функций

# %% [markdown]
# Обратим внимание на наиболее коррелирующие признаки:
# TotalWorkingYears и JobLevel, MonthlyIncome и JobLevel, MonthlyIncome и TotalWorkingYears, PercentSalaryHike и PerformanceRating, YearsInCurrentRole и YearsAtCompany, YearsWithCurrManager и YearsAtCompany, YearsWithCurrManager и YearsInCurrentRole плюс можно еще отнести Age и TotalWorkingYears (~ 0.7)

# %% [markdown]
# Рассмотрим распределения последних 15 признаков.

# %%
data.columns[15:]
# Out:
# Index(['MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# MonthlyIncome

# %%
f, axes = plt.subplots(1, 2, figsize=(25,10))

sns.distplot(data['MonthlyIncome'], ax = axes[0])
axes[0].set_xlabel('MonthlyIncome', fontsize = 20)
axes[0].set_ylabel('Count', fontsize=20)
axes[0].yaxis.tick_left()

ax = sns.boxenplot(x = 'Attrition', y = 'MonthlyIncome', data = data, palette= colors,  ax = axes[1])
ax = sns.stripplot(x = "Attrition", y = "MonthlyIncome", data=data, color="gray", size = 3)
axes[1].set_xlabel('Attrition', fontsize = 20)
axes[1].set_ylabel('MonthlyIncome', fontsize = 20)
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

plt.show()

# %% [markdown]
# Попробуем убрать часть хвоста в распределении (значения, которые входят в аномальные). Порог - 16500

# %%
data_out = data.loc[data['MonthlyIncome'] < 16500]
data_out.shape
# Out:
# (1355, 31)

# %%
data.groupby('Attrition').JobLevel.value_counts(normalize=True)
# Out:
# Attrition  JobLevel
# No         2           0.390916
#            1           0.324412
#            3           0.150852
#            4           0.081914
#            5           0.051906
# Yes        1           0.603376
#            2           0.219409
#            3           0.135021
#            4           0.021097
#            5           0.021097
# Name: JobLevel, dtype: float64

# %%
f, axes = plt.subplots(1, 2, figsize=(27,12))

f = sns.countplot('JobLevel',data=data, palette=colors, hue = 'Attrition', ax = axes[0])
axes[0].set_xlabel('JobLevel', fontsize = 20)
axes[0].set_ylabel('Count', fontsize=20)
axes[0].yaxis.tick_left()


ax = sns.boxenplot(x = 'JobLevel', y = 'MonthlyIncome', data = data, hue = 'Attrition', palette=colors, ax = axes[1])
#ax = sns.stripplot(x = "JobLevel", y = "MonthlyIncome", data=data, color="gray", size = 3)
axes[1].set_xlabel('JobLevel', fontsize = 20)
axes[1].set_ylabel('MonthlyIncome', fontsize = 20)
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()


plt.show()

# %% [markdown]
# Т.е чем выше JobLevel, тем выше MonthlyIncome. Среди выбывших почти 40% имеют JobLevel = 2 b и 32% JobLevel = 1.

# %%
data.PerformanceRating.value_counts()
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# PerformanceRating (рейтинг производительности):
# 1. 'Low'
# 2. 'Good'
# 3. 'Excellent'
# 4. ‘Outstanding'

# %%
 data[data.Attrition == 'No'].PerformanceRating.value_counts()
# Out:
# 3    1044
# 4     189
# Name: PerformanceRating, dtype: int64

# %%
 data[data.Attrition == 'Yes'].PerformanceRating.value_counts()
# Out:
# 3    200
# 4     37
# Name: PerformanceRating, dtype: int64

# %%
f, axes = plt.subplots(1, 2, figsize=(25,10))

f = data.PerformanceRating.value_counts().plot.pie(explode=[0,0.20], colors=colors, autopct='%1.1f%%',  ax=axes[0])
axes[0].set_xlabel('PerformanceRating', fontsize = 20)
axes[0].set_ylabel('Count', fontsize=20)
axes[0].yaxis.tick_left()


ax = sns.countplot('PerformanceRating',data=data, palette=colors, hue = 'Attrition', ax = axes[1])
axes[1].set_xlabel('PerformanceRating', fontsize = 20)
axes[1].set_ylabel('Count', fontsize=20)
axes[1].yaxis.tick_left()


plt.show()

# %% [markdown]
# В наших данных рейтинг производительности у всех сотрудников 'Excellent' или 'Outstanding'. А процентное соотношение 'Excellent' и 'Outstanding' среди действующих и выбывших сотрудников одинаково (около 15% с максимальным рейтингом).

# %%
data.TotalWorkingYears.unique()
# Out:
# array([ 8, 10,  7,  6, 12,  1, 17,  5,  3, 31, 13,  0, 26, 24, 22,  9, 19,
#         2, 23, 14, 15,  4, 29, 28, 21, 25, 20, 11, 16, 37, 38, 30, 40, 18,
#        36, 34, 32, 33, 35, 27])

# %%
f, axes = plt.subplots(1, 2, figsize=(25,10))

sns.distplot(data['YearsAtCompany'], ax = axes[0])
axes[0].set_xlabel('YearsAtCompany', fontsize = 20)
axes[0].set_ylabel('Count', fontsize=20)
axes[0].yaxis.tick_left()

ax = sns.boxenplot(x = 'Attrition', y = 'YearsAtCompany', data = data, palette= colors,  ax = axes[1])
#ax = sns.stripplot(x = "Attrition", y = "TotalWorkingYears", data=data, color="gray", size = 3)
axes[1].set_xlabel('Attrition', fontsize = 20)
axes[1].set_ylabel('YearsAtCompany', fontsize = 20)
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

plt.show()

# %% [markdown]
# убираем выбросы

# %%
data_out = data_out.loc[data_out['YearsAtCompany'] < 18]

# %%
f, axes = plt.subplots(1, 2, figsize=(25,10))

sns.distplot(data['TotalWorkingYears'], ax = axes[0])
axes[0].set_xlabel('TotalWorkingYears', fontsize = 20)
axes[0].set_ylabel('Count', fontsize=20)
axes[0].yaxis.tick_left()

ax = sns.boxenplot(x = 'Attrition', y = 'TotalWorkingYears', data = data, palette= colors,  ax = axes[1])
ax = sns.stripplot(x = "Attrition", y = "TotalWorkingYears", data=data, color="gray", size = 3)
axes[1].set_xlabel('Attrition', fontsize = 20)
axes[1].set_ylabel('TotalWorkingYears', fontsize = 20)
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

plt.show()

# %%
#YearsSinceLastPromotion
data_out.loc[data_out['TotalWorkingYears'] < 25]
data_out.shape
# Out:
# (1292, 31)

# %%
data.YearsWithCurrManager
# Out:
# EmployeeNumber
# 1       5
# 2       7
# 4       0
# 5       0
# 7       2
#        ..
# 2061    3
# 2062    7
# 2064    3
# 2065    8
# 2068    2
# Name: YearsWithCurrManager, Length: 1470, dtype: int64

# %%
f, axes = plt.subplots(1, 2, figsize=(25,10))

sns.distplot(data['YearsWithCurrManager'], ax = axes[0])
axes[0].set_xlabel('YearsWithCurrManager', fontsize = 20)
axes[0].set_ylabel('Count', fontsize=20)
axes[0].yaxis.tick_left()

ax = sns.boxenplot(x = 'Attrition', y = 'YearsWithCurrManager', data = data, palette= colors,  ax = axes[1])
ax = sns.stripplot(x = "Attrition", y = "YearsWithCurrManager", data=data, color="gray", size = 3)
axes[1].set_xlabel('Attrition', fontsize = 20)
axes[1].set_ylabel('YearsWithCurrManager', fontsize = 20)
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

plt.show()

# %%
#YearsSinceLastPromotion
data_out = data_out.loc[data['YearsWithCurrManager'] < 12]
data_out.shape
# Out:
# (1271, 31)

# %%
columns = ['Age', 'MonthlyIncome', 'YearsAtCompany', 'JobLevel', 'Attrition']

# %% [markdown]
# pairplot показывает отношения между всеми парами переменных. Рассмотрим те признаки, которые имеют среднюю корреляцию (~0.5)

# %%
colors = ['#c9e5f4', '#7f548f']
sns.pairplot(data[columns], height = 5, hue = 'Attrition', kind="scatter", palette=colors)

# %% [markdown]
# Закономерности:
# 1. Чем больше возраст, тем выше месячный доход (почти нет тех, кто до 40 получает высокую зарплату)
# 2. Чем выше уровень занимаемой должности, тем выше месячный доход.
# Исходя из этого, как факт никто не достигает уровня занимаемой должности 4-5 в возрасте до 30 лет (5 - только после 40).
# Но также и нет сотрудников, которые после 20 лет в компании имеют уровень занимаемой должности - 1 и 2.

# %% [markdown]
# 3. В основном, сотрудники, которые проработали больше 25 лет в компании, имеют месячный доход выше среднего. Соответственно, если сотрудник в компании больше 20 лет, то уровень занимаемой должности больше 3 (не считая уволенных сотрудников, которые проработали в компании 30 и 40 лет).

# %%
data.loc[(data.Attrition == 'Yes') & (data.JobLevel == 3) & (data.YearsAtCompany > 30)]
# Out:
#                 Age Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 165              58       Yes  Travel_Rarely        147
# 1572             53       Yes  Travel_Rarely        607
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 165             Research & Development                23          4
# 1572            Research & Development                 2          5
#
#                   EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                     ...
# 165                      Medical                        4  Female  ...
# 1572            Technical Degree                        3  Female  ...
#
#                 PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# EmployeeNumber
# 165                             3                         4                 1
# 1572                            3                         2                 1
#
#                TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# EmployeeNumber
# 165                           40                      3               2
# 1572                          34                      4               3
#
#                 YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 165                         40                  10                       15
# 1572                        33                   7                        1
#
#                YearsWithCurrManager
# EmployeeNumber
# 165                               6
# 1572                              9
#
# [2 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
Yes = data[data.Attrition == "Yes"]
No = data[data.Attrition == "No"]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 6)
sns.countplot(x = 'Age', data = data)
ax.set_xlabel('Age', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Age Count Distribution', fontsize=15)
sns.despine()

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (25, 10))
#sns.boxplot(x = 'Age', data = data, orient = 'v', ax = ax1)
sns.boxenplot(x = 'Attrition', y = 'Age', data = data, palette= colors,  ax = ax1)
ax1.set_xlabel('People Age', fontsize=15)
ax1.set_ylabel('Age', fontsize=15)
ax1.set_title('Age Distribution', fontsize=15)
ax1.tick_params(labelsize=15)


sns.distplot(data['Age'], ax = ax2)
sns.despine(ax = ax2)
ax2.set_xlabel('Age', fontsize=15)
ax2.set_ylabel('Occurence', fontsize=15)
ax2.set_title('Age x Ocucurence', fontsize=15)
ax2.tick_params(labelsize=15)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()

# %% [markdown]
# выбросов вообще нет

# %%
print('1º Quartile: ', data['Age'].quantile(q = 0.25))
print('2º Quartile: ', data['Age'].quantile(q = 0.50))
print('3º Quartile: ', data['Age'].quantile(q = 0.75))
# Out:
# 1º Quartile:  30.0
# 2º Quartile:  36.0
# 3º Quartile:  43.0

# %%
#function to creat group of ages, this helps because we have 78 differente values here
def age(dataframe):
    dataframe.loc[dataframe['Age'] <= 30, 'Age'] = 1
    dataframe.loc[(dataframe['Age'] > 30) & (dataframe['Age'] <= 45), 'Age'] = 2
    dataframe.loc[dataframe['Age'] > 45, 'Age'] = 3
           
    return dataframe

age(data).head()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                 2       Yes      Travel_Rarely       1102
# 2                 3        No  Travel_Frequently        279
# 4                 2       Yes      Travel_Rarely       1373
# 5                 2        No  Travel_Frequently       1392
# 7                 1        No      Travel_Rarely        591
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
#
#                EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                  ...
# 1               Life Sciences                        2  Female  ...
# 2               Life Sciences                        3    Male  ...
# 4                       Other                        4    Male  ...
# 5               Life Sciences                        4  Female  ...
# 7                     Medical                        1    Male  ...
#
#                 PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# EmployeeNumber
# 1                               3                         1                 0
# 2                               4                         4                 1
# 4                               3                         2                 0
# 5                               3                         3                 0
# 7                               3                         4                 1
#
#                TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# EmployeeNumber
# 1                              8                      0               1
# 2                             10                      3               3
# 4                              7                      3               3
# 5                              8                      3               3
# 7                              6                      3               3
#
#                 YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1                            6                   4                        0
# 2                           10                   7                        1
# 4                            0                   0                        0
# 5                            8                   7                        3
# 7                            2                   2                        2
#
#                YearsWithCurrManager
# EmployeeNumber
# 1                                 5
# 2                                 7
# 4                                 0
# 5                                 0
# 7                                 2
#
# [5 rows x 31 columns]

# %%
data_encoding = data.copy()
data_encoding_target = data_encoding.Attrition
data_encoding.drop(['Attrition'], axis = 1, inplace=True)

# %%
data.Attrition = [1 if each == "Yes" else 0 for each in data.Attrition]
data_target = data.Attrition
data.drop(['Attrition'], axis = 1, inplace=True)

# %%
cat_columns = data_encoding.columns[data_encoding.dtypes == 'object']
cat_columns
# Out:
# Index(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus', 'OverTime'],
#       dtype='object')

# %% [markdown]
#  Закодируем признаки, в которых меньше 2 значений LabelEncoding, а где больше 2 - OneHotEncoding.

# %%
from sklearn.preprocessing import LabelEncoder
pd.options.display.max_columns = 40

labelencoder_X = LabelEncoder()
data['Gender'] = labelencoder_X.fit_transform(data['Gender'])  
data['OverTime'] = labelencoder_X.fit_transform(data['OverTime'])
data.head()
# Out:
#                 Age     BusinessTravel  DailyRate              Department  \
# EmployeeNumber
# 1                41      Travel_Rarely       1102                   Sales
# 2                49  Travel_Frequently        279  Research & Development
# 4                37      Travel_Rarely       1373  Research & Development
# 5                33  Travel_Frequently       1392  Research & Development
# 7                27      Travel_Rarely        591  Research & Development
#
#                 DistanceFromHome  Education EducationField  \
# EmployeeNumber
# 1                              1          2  Life Sciences
# 2                              8          1  Life Sciences
# 4                              2          2          Other
# 5                              3          4  Life Sciences
# 7                              2          1        Medical
#
#                 EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  \
# EmployeeNumber
# 1                                     2       0          94               3
# 2                                     3       1          61               2
# 4                                     4       1          92               2
# 5                                     4       0          56               3
# 7                                     1       1          40               3
#
#                 JobLevel                JobRole  JobSatisfaction  \
# EmployeeNumber
# 1                      2        Sales Executive                4
# 2                      2     Research Scientist                2
# 4                      1  Laboratory Technician                3
# 5                      1     Research Scientist                3
# 7                      1  Laboratory Technician                2
#
#                MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# EmployeeNumber
# 1                     Single           5993        19479                   8
# 2                    Married           5130        24907                   1
# 4                     Single           2090         2396                   6
# 5                    Married           2909        23159                   1
# 7                    Married           3468        16632                   9
#
#                 OverTime  PercentSalaryHike  PerformanceRating  \
# EmployeeNumber
# 1                      1                 11                  3
# 2                      0                 23                  4
# 4                      1                 15                  3
# 5                      1                 11                  3
# 7                      0                 12                  3
#
#                 RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# EmployeeNumber
# 1                                      1                 0                  8
# 2                                      4                 1                 10
# 4                                      2                 0                  7
# 5                                      3                 0                  8
# 7                                      4                 1                  6
#
#                 TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# EmployeeNumber
# 1                                   0                1               6
# 2                                   3                3              10
# 4                                   3                3               0
# 5                                   3                3               8
# 7                                   3                3               2
#
#                 YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1                                4                        0
# 2                                7                        1
# 4                                0                        0
# 5                                7                        3
# 7                                2                        2
#
#                 YearsWithCurrManager
# EmployeeNumber
# 1                                  5
# 2                                  7
# 4                                  0
# 5                                  0
# 7                                  2

# %%
cat_columns = cat_columns.drop("Gender")
cat_columns = cat_columns.drop("OverTime")

# %%
dataset_preprocessed = pd.get_dummies(data, columns=cat_columns)
dataset_preprocessed
# Out:
#                 Age  DailyRate  DistanceFromHome  Education  \
# EmployeeNumber
# 1                41       1102                 1          2
# 2                49        279                 8          1
# 4                37       1373                 2          2
# 5                33       1392                 3          4
# 7                27        591                 2          1
# ...             ...        ...               ...        ...
# 2061             36        884                23          2
# 2062             39        613                 6          1
# 2064             27        155                 4          3
# 2065             49       1023                 2          3
# 2068             34        628                 8          3
#
#                 EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  \
# EmployeeNumber
# 1                                     2       0          94               3
# 2                                     3       1          61               2
# 4                                     4       1          92               2
# 5                                     4       0          56               3
# 7                                     1       1          40               3
# ...                                 ...     ...         ...             ...
# 2061                                  3       1          41               4
# 2062                                  4       1          42               2
# 2064                                  2       1          87               4
# 2065                                  4       1          63               2
# 2068                                  2       1          82               4
#
#                 JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# EmployeeNumber
# 1                      2                4           5993        19479
# 2                      2                2           5130        24907
# 4                      1                3           2090         2396
# 5                      1                3           2909        23159
# 7                      1                2           3468        16632
# ...                  ...              ...            ...          ...
# 2061                   2                4           2571        12290
# 2062                   3                1           9991        21457
# 2064                   2                2           6142         5174
# 2065                   2                2           5390        13243
# 2068                   2                3           4404        10228
#
#                 NumCompaniesWorked  OverTime  PercentSalaryHike  \
# EmployeeNumber
# 1                                8         1                 11
# 2                                1         0                 23
# 4                                6         1                 15
# 5                                1         1                 11
# 7                                9         0                 12
# ...                            ...       ...                ...
# 2061                             4         0                 17
# 2062                             4         0                 15
# 2064                             1         1                 20
# 2065                             2         0                 14
# 2068                             2         0                 12
#
#                 PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# EmployeeNumber
# 1                               3                         1                 0
# 2                               4                         4                 1
# 4                               3                         2                 0
# 5                               3                         3                 0
# 7                               3                         4                 1
# ...                           ...                       ...               ...
# 2061                            3                         3                 1
# 2062                            3                         1                 1
# 2064                            4                         2                 1
# 2065                            3                         4                 0
# 2068                            3                         1                 0
#
#                 TotalWorkingYears  TrainingTimesLastYear  ...  \
# EmployeeNumber                                            ...
# 1                               8                      0  ...
# 2                              10                      3  ...
# 4                               7                      3  ...
# 5                               8                      3  ...
# 7                               6                      3  ...
# ...                           ...                    ...  ...
# 2061                           17                      3  ...
# 2062                            9                      5  ...
# 2064                            6                      0  ...
# 2065                           17                      3  ...
# 2068                            6                      3  ...
#
#                 Department_Research & Development  Department_Sales  \
# EmployeeNumber
# 1                                               0                 1
# 2                                               1                 0
# 4                                               1                 0
# 5                                               1                 0
# 7                                               1                 0
# ...                                           ...               ...
# 2061                                            1                 0
# 2062                                            1                 0
# 2064                                            1                 0
# 2065                                            0                 1
# 2068                                            1                 0
#
#                 EducationField_Human Resources  EducationField_Life Sciences  \
# EmployeeNumber
# 1                                            0                             1
# 2                                            0                             1
# 4                                            0                             0
# 5                                            0                             1
# 7                                            0                             0
# ...                                        ...                           ...
# 2061                                         0                             0
# 2062                                         0                             0
# 2064                                         0                             1
# 2065                                         0                             0
# 2068                                         0                             0
#
#                 EducationField_Marketing  EducationField_Medical  \
# EmployeeNumber
# 1                                      0                       0
# 2                                      0                       0
# 4                                      0                       0
# 5                                      0                       0
# 7                                      0                       1
# ...                                  ...                     ...
# 2061                                   0                       1
# 2062                                   0                       1
# 2064                                   0                       0
# 2065                                   0                       1
# 2068                                   0                       1
#
#                 EducationField_Other  EducationField_Technical Degree  \
# EmployeeNumber
# 1                                  0                                0
# 2                                  0                                0
# 4                                  1                                0
# 5                                  0                                0
# 7                                  0                                0
# ...                              ...                              ...
# 2061                               0                                0
# 2062                               0                                0
# 2064                               0                                0
# 2065                               0                                0
# 2068                               0                                0
#
#                 JobRole_Healthcare Representative  JobRole_Human Resources  \
# EmployeeNumber
# 1                                               0                        0
# 2                                               0                        0
# 4                                               0                        0
# 5                                               0                        0
# 7                                               0                        0
# ...                                           ...                      ...
# 2061                                            0                        0
# 2062                                            1                        0
# 2064                                            0                        0
# 2065                                            0                        0
# 2068                                            0                        0
#
#                 JobRole_Laboratory Technician  JobRole_Manager  \
# EmployeeNumber
# 1                                           0                0
# 2                                           0                0
# 4                                           1                0
# 5                                           0                0
# 7                                           1                0
# ...                                       ...              ...
# 2061                                        1                0
# 2062                                        0                0
# 2064                                        0                0
# 2065                                        0                0
# 2068                                        1                0
#
#                 JobRole_Manufacturing Director  JobRole_Research Director  \
# EmployeeNumber
# 1                                            0                          0
# 2                                            0                          0
# 4                                            0                          0
# 5                                            0                          0
# 7                                            0                          0
# ...                                        ...                        ...
# 2061                                         0                          0
# 2062                                         0                          0
# 2064                                         1                          0
# 2065                                         0                          0
# 2068                                         0                          0
#
#                 JobRole_Research Scientist  JobRole_Sales Executive  \
# EmployeeNumber
# 1                                        0                        1
# 2                                        1                        0
# 4                                        0                        0
# 5                                        1                        0
# 7                                        0                        0
# ...                                    ...                      ...
# 2061                                     0                        0
# 2062                                     0                        0
# 2064                                     0                        0
# 2065                                     0                        1
# 2068                                     0                        0
#
#                 JobRole_Sales Representative  MaritalStatus_Divorced  \
# EmployeeNumber
# 1                                          0                       0
# 2                                          0                       0
# 4                                          0                       0
# 5                                          0                       0
# 7                                          0                       0
# ...                                      ...                     ...
# 2061                                       0                       0
# 2062                                       0                       0
# 2064                                       0                       0
# 2065                                       0                       0
# 2068                                       0                       0
#
#                 MaritalStatus_Married  MaritalStatus_Single
# EmployeeNumber
# 1                                   0                     1
# 2                                   1                     0
# 4                                   0                     1
# 5                                   1                     0
# 7                                   1                     0
# ...                               ...                   ...
# 2061                                1                     0
# 2062                                1                     0
# 2064                                1                     0
# 2065                                1                     0
# 2068                                1                     0
#
# [1470 rows x 49 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, Y_train, Y_test = train_test_split(data
                                                ,data_target, test_size = 0.3, random_state=100, stratify=data_target)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-a1300e49e468> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#       2
#       3 x_train, x_test, Y_train, Y_test = train_test_split(data
#       4                                                 ,data_target, test_size = 0.3, random_state=100, stratify=data_target)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dataset_preprocessed
                                                ,data_target, test_size = 0.3, random_state=100, stratify=data_target)

# %%
# !pip3 install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/site-packages (0.6.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from imbalanced-learn) (0.14.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/site-packages (from imbalanced-learn) (0.23.0)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.7/site-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/site-packages (from imbalanced-learn) (1.18.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn>=0.22->imbalanced-learn) (2.0.0)

# %%
#oversampler=SMOTE(random_state=0)
#smote_train, smote_target = oversampler.fit_sample(X_train, y_train,)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-154c957b536d> in <module>
# ----> 1 from sklearn.model_selection import KFold
#       2 from sklearn.model_selection import cross_val_score
#       3 from sklearn.metrics import confusion_matrix, accuracy_score
#       4
#       5 k_fold = KFold(n_splits=10, shuffle=True, random_state=0)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Cross val metric
def cross_val_metrics(model) :
    scores = ['accuracy', 'precision', 'recall']
    for sc in scores:
        scores = cross_val_score(model, dataset_preprocessed, data_target, cv = k_fold, scoring = sc)
        print('[%s] : %0.5f (+/- %0.5f)'%(sc, scores.mean(), scores.std()))

# %%
from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()

X_train_scaled = sc_X.fit_transform(X_train)
X_test_scaled = sc_X.transform(X_test)

# %% [markdown]
# чем больше параметр C, тем более сложные зависимости в данных может восстанавливать модель

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(C=1e4, fit_intercept=True, max_iter=1000, penalty = 'l2', solver='liblinear')

pred = model.fit(X_train,y_train).predict(X_test)


print(confusion_matrix(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
# [[362   8]
#  [ 45  26]]
# 0.8798185941043084

# %%
cross_val_metrics(model)
# Out:
# [accuracy] : 0.87279 (+/- 0.02756)
# [precision] : 0.83848 (+/- 0.13436)
# [recall] : 0.28265 (+/- 0.09590)

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier_knn = KNeighborsClassifier(leaf_size = 1, metric = 'minkowski', n_neighbors = 32, weights = 'distance')
knn = classifier_knn.fit(X_train, y_train).predict(X_test)

print(confusion_matrix(y_test, knn))
print(accuracy_score(y_test, knn))
# Out:
# [[370   0]
#  [ 71   0]]
# 0.8390022675736961

# %%
cross_val_metrics(classifier_knn)
# Out:
# [accuracy] : 0.83946 (+/- 0.02937)
# [precision] : 0.35000 (+/- 0.45000)
# [recall] : 0.01622 (+/- 0.02032)

# %%
from sklearn.svm import SVC

svc = SVC(kernel = 'sigmoid')
pred = svc.fit(X_train, y_train).predict(X_test)

print(confusion_matrix(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
# [[370   0]
#  [ 71   0]]
# 0.8390022675736961

# %%
cross_val_metrics(svc)
# Out:
# [accuracy] : 0.83878 (+/- 0.02822)
# [precision] : 0.00000 (+/- 0.00000)
# [recall] : 0.00000 (+/- 0.00000)

# %%
from sklearn.tree import DecisionTreeClassifier

classifier_dt = DecisionTreeClassifier(max_features=10, max_leaf_nodes=400, random_state = 33)
tree = classifier_dt.fit(X_train, y_train).predict(X_test)

print(confusion_matrix(y_test, tree))
print(accuracy_score(y_test, tree))
# Out:
# [[324  46]
#  [ 58  13]]
# 0.764172335600907

# %%
cross_val_metrics(classifier_dt)
# Out:
# [accuracy] : 0.77619 (+/- 0.02442)
# [precision] : 0.32203 (+/- 0.07661)
# [recall] : 0.35277 (+/- 0.06937)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rf = RandomForestClassifier(criterion = 'entropy', max_features = 4, n_estimators = 800, random_state=33)
class_ = classifier_rf.fit(X_train, y_train).predict(X_test)

print(confusion_matrix(y_test, class_))
print(accuracy_score(y_test, class_))
# Out:
# [[370   0]
#  [ 63   8]]
# 0.8571428571428571

# %%
cross_val_metrics(classifier_rf)
# Out:
# [accuracy] : 0.85714 (+/- 0.02902)
# [precision] : 0.91333 (+/- 0.15578)
# [recall] : 0.13364 (+/- 0.04365)

# %%
importances = classifier_rf.feature_importances_
indices = np.argsort(importances)[::-1] # Sort feature importances in descending order
names = [X_train.columns[i] for i in indices] # Rearrange feature names so they match the sorted feature importances
plt.figure(figsize=(15, 7)) # Create plot
plt.title("Feature Importance") # Create plot title
plt.bar(range(X_train.shape[1]), importances[indices]) # Add bars
plt.xticks(range(X_train.shape[1]), names, rotation=90) # Add feature names as x-axis labels
plt.show() # Show plot

# %%
params = {
    'objective': 'binary:logistic',
    'max_depth': 5,
    'eta': 0.01,
    'subsample': 0.5,
    'min_child_weight': 1,
    'colsample_bytree':0.6
}
trees = 1500

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import average_precision_score

cb = CatBoostClassifier(silent=True, max_depth=5, learning_rate=0.03, n_estimators=1400)

new = cb.fit(x_train, Y_train, cat_features = cat_columns)
average_precision_score(Y_test, cb.predict_proba(x_test)[:,1])
# Out:
# 0.6004126878623718

# %%
# !pip3 install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/site-packages (from lightgbm) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from lightgbm) (1.18.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from lightgbm) (0.23.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from scikit-learn->lightgbm) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->lightgbm) (2.0.0)

# %%
cross_val_metrics(cb)
# Out:
# [accuracy] : 0.87347 (+/- 0.03251)
# [precision] : 0.75549 (+/- 0.11732)
# [recall] : 0.33261 (+/- 0.07050)

# %%
import lightgbm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-b18b3f8a6dc8> in <module>
# ----> 1 import lightgbm
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
cb = CatBoostClassifier(silent=True, max_depth=5, learning_rate=0.03, n_estimators=1400, task_type='GPU').fit(numof(X_train), y_train)
print(average_precision_score(y_test, cb.predict_proba(numof(X_test))[:,1]))
